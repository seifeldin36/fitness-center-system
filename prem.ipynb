# %% [markdown]
# <a href="https://colab.research.google.com/github/seifeldin36/fitness-center-system/blob/master/prem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/player_stats.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         571 non-null    object
#  1   nation                       568 non-null    object
#  2   position                     571 non-null    object
#  3   team                         571 non-null    object
#  4   age                          568 non-null    float64
#  5   born                         568 non-null    float64
#  6   played                       571 non-null    int64
#  7   starts                       571 non-null    int64
#  8   minutes                      571 non-null    int64
#  9   goals                        571 non-null    int64
#  10  assists                      571 non-null    int64
#  11  penalty_kicks                571 non-null    int64
#  12  penalty_kick_attempts        571 non-null    int64
# ...

# %%
data.isna().sum()
# Out:
# name                           0
# nation                         3
# position                       0
# team                           0
# age                            3
# born                           3
# played                         0
# starts                         0
# minutes                        0
# goals                          0
# assists                        0
# penalty_kicks                  0
# penalty_kick_attempts          0
# yellow                         0
# red                            0
# expected_goals                 0
# progressive_carries            0
# progressive_passes             0
# received_progressive_passes    0
# dtype: int64

# %%
mask = data['nation'].isna()
data[mask]
# Out:
#              name nation position            team  age  born  played  starts  \
# 169    Jake Evans    NaN       FW  Leicester City  NaN   NaN       3       0
# 324   Mateus Mane    NaN       MF          Wolves  NaN   NaN       1       0
# 356  Jeremy Monga    NaN    FW,MF  Leicester City  NaN   NaN       6       0
#
#      minutes  goals  assists  penalty_kicks  penalty_kick_attempts  yellow  \
# 169       19      0        0              0                      0       0
# 324        2      0        0              0                      0       0
# 356       93      0        0              0                      0       0
#
#      red  expected_goals  progressive_carries  progressive_passes  \
# 169    0             0.0                    0                   0
# 324    0             0.0                    0                   0
# 356    0             0.2                    6                   3
#
#      received_progressive_passes
# 169                            1
# ...

# %%
# Select rows where the name is 'Jake Evans' and fill the missing 'nation' values
data.loc[data['name'] == 'Jake Evans', 'nation'] = data.loc[data['name'] == 'Jake Evans', 'nation'].fillna('England')

# %%
data.loc[data['name']== 'Mateus Mane','nation'] = data.loc[data['name']== 'Mateus Mane','nation'].fillna('Portugal')

# %%
data.loc[data['name']=='Jeremy Monga','nation'] = data.loc[data['name']=='Jeremy Monga','nation'].fillna('England')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         571 non-null    object
#  1   nation                       571 non-null    object
#  2   position                     571 non-null    object
#  3   team                         571 non-null    object
#  4   age                          568 non-null    float64
#  5   born                         568 non-null    float64
#  6   played                       571 non-null    int64
#  7   starts                       571 non-null    int64
#  8   minutes                      571 non-null    int64
#  9   goals                        571 non-null    int64
#  10  assists                      571 non-null    int64
#  11  penalty_kicks                571 non-null    int64
#  12  penalty_kick_attempts        571 non-null    int64
# ...

# %%
mask_age = data['age'].isna()
data[mask_age]
# Out:
#              name    nation position            team  age  born  played  \
# 169    Jake Evans   England       FW  Leicester City  NaN   NaN       3
# 324   Mateus Mane  Portugal       MF          Wolves  NaN   NaN       1
# 356  Jeremy Monga   England    FW,MF  Leicester City  NaN   NaN       6
#
#      starts  minutes  goals  assists  penalty_kicks  penalty_kick_attempts  \
# 169       0       19      0        0              0                      0
# 324       0        2      0        0              0                      0
# 356       0       93      0        0              0                      0
#
#      yellow  red  expected_goals  progressive_carries  progressive_passes  \
# 169       0    0             0.0                    0                   0
# 324       0    0             0.0                    0                   0
# 356       0    0             0.2                    6                   3
#
#      received_progressive_passes
# 169                            1
# ...

# %%
# Select rows where the name is 'Jake Evans' and fill the missing 'nation' values
data.loc[data['name'] == 'Jake Evans', 'age'] = data.loc[data['name'] == 'Jake Evans', 'age'].fillna('17')
data.loc[data['name']== 'Mateus Mane','age'] = data.loc[data['name']== 'Mateus Mane','age'].fillna('17')
data.loc[data['name']=='Jeremy Monga','age'] = data.loc[data['name']=='Jeremy Monga','age'].fillna('16')
# Out:
# /tmp/ipython-input-3657065149.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['17']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[data['name'] == 'Jake Evans', 'age'] = data.loc[data['name'] == 'Jake Evans', 'age'].fillna('17')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         571 non-null    object
#  1   nation                       571 non-null    object
#  2   position                     571 non-null    object
#  3   team                         571 non-null    object
#  4   age                          571 non-null    object
#  5   born                         568 non-null    float64
#  6   played                       571 non-null    int64
#  7   starts                       571 non-null    int64
#  8   minutes                      571 non-null    int64
#  9   goals                        571 non-null    int64
#  10  assists                      571 non-null    int64
#  11  penalty_kicks                571 non-null    int64
#  12  penalty_kick_attempts        571 non-null    int64
# ...

# %%
# Select rows where the name is 'Jake Evans' and fill the missing 'nation' values
data.loc[data['name'] == 'Jake Evans', 'born'] = data.loc[data['name'] == 'Jake Evans', 'born'].fillna('2008')
data.loc[data['name']== 'Mateus Mane','born'] = data.loc[data['name']== 'Mateus Mane','born'].fillna('2008')
data.loc[data['name']=='Jeremy Monga','born'] = data.loc[data['name']=='Jeremy Monga','born'].fillna('2009')
# Out:
# /tmp/ipython-input-1020894060.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['2008']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[data['name'] == 'Jake Evans', 'born'] = data.loc[data['name'] == 'Jake Evans', 'born'].fillna('2008')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         571 non-null    object
#  1   nation                       571 non-null    object
#  2   position                     571 non-null    object
#  3   team                         571 non-null    object
#  4   age                          571 non-null    object
#  5   born                         571 non-null    object
#  6   played                       571 non-null    int64
#  7   starts                       571 non-null    int64
#  8   minutes                      571 non-null    int64
#  9   goals                        571 non-null    int64
#  10  assists                      571 non-null    int64
#  11  penalty_kicks                571 non-null    int64
#  12  penalty_kick_attempts        571 non-null    int64
# ...

# %%
data.head()
# Out:
#                 name         nation position         team   age    born  \
# 0         Max Aarons        England       DF  Bournemouth  25.0  2000.0
# 1  Joshua Acheampong        England       DF      Chelsea  19.0  2006.0
# 2        Tyler Adams  United States       MF  Bournemouth  26.0  1999.0
# 3   Tosin Adarabioyo        England       DF      Chelsea  27.0  1997.0
# 4      Simon Adingra   Cote dIvoire    FW,MF     Brighton  23.0  2002.0
#
#    played  starts  minutes  goals  assists  penalty_kicks  \
# 0       3       1       86      0        0              0
# 1       4       2      170      0        0              0
# 2      27      20     1875      0        3              0
# 3      21      14     1319      1        1              0
# 4      28      11     1052      2        2              0
#
#    penalty_kick_attempts  yellow  red  expected_goals  progressive_carries  \
# 0                      0       0    0             0.0                    1
# ...

# %%
#Show how many goals for each team "descinding oreder"
data.groupby('team')['goals'].sum().sort_values(ascending=False)
# Out:
# team
# Liverpool          84
# Manchester City    69
# Newcastle Utd      66
# Arsenal            65
# Brentford          64
# Tottenham          60
# Chelsea            60
# Brighton           60
# Nott'ham Forest    57
# Aston Villa        56
# Bournemouth        55
# Fulham             53
# Wolves             52
# Crystal Palace     48
# West Ham           40
# Manchester Utd     40
# Everton            38
# Ipswich Town       34
# Leicester City     33
# Southampton        24
# Name: goals, dtype: int64

# %%
#Show The top 10 player scored goals
data.groupby('name')['goals'].sum().sort_values(ascending=False).head(10)
# Out:
# name
# Mohamed Salah           28
# Alexander Isak          23
# Erling Haaland          21
# Chris Wood              20
# Yoane Wissa             19
# Bryan Mbeumo            19
# Ollie Watkins           16
# Matheus Cunha           15
# Cole Palmer             15
# Jørgen Strand Larsen    14
# Name: goals, dtype: int64

# %%
#Show The top 10 players made assists
data.groupby('name')['assists'].sum().sort_values(ascending=False).head(10)
# Out:
# name
# Mohamed Salah       18
# Jacob Murphy        12
# Anthony Elanga      11
# Morgan Rogers       10
# Antonee Robinson    10
# Bukayo Saka         10
# Mikkel Damsgaard    10
# Son Heung-min        9
# Bruno Fernandes      9
# Ollie Watkins        8
# Name: assists, dtype: int64

# %%
#Show The top 10 players got red card
data.groupby('name')['red'].sum().sort_values(ascending=False).head(10)
# Out:
# name
# Myles Lewis-Skelly    2
# Bruno Fernandes       2
# Jack Stephens         2
# Lewis Cook            1
# Declan Rice           1
# Joachim Andersen      1
# Morgan Gibbs-White    1
# Rayan Aït-Nouri       1
# Ashley Young          1
# Mohammed Kudus        1
# Name: red, dtype: int64

# %%
#Show The top 10 scored by penalty
data.groupby('name')['penalty_kicks'].sum().sort_values(ascending=False).head(10)
# Out:
# name
# Mohamed Salah      9
# Justin Kluivert    6
# João Pedro         5
# Bryan Mbeumo       5
# Cole Palmer        4
# Alexander Isak     4
# Raúl Jiménez       3
# Chris Wood         3
# Bruno Fernandes    3
# Liam Delap         2
# Name: penalty_kicks, dtype: int64

# %%
#Show The top 10 players got red card
data.groupby('name')[['penalty_kick_attempts','penalty_kicks','team']].sum().sort_values(by= 'penalty_kick_attempts',ascending=False).head(10)
# Out:
#                  penalty_kick_attempts  penalty_kicks             team
# name
# Mohamed Salah                        9              9        Liverpool
# Bryan Mbeumo                         6              5        Brentford
# Justin Kluivert                      6              6      Bournemouth
# Cole Palmer                          5              4          Chelsea
# João Pedro                           5              5         Brighton
# Alexander Isak                       4              4    Newcastle Utd
# Raúl Jiménez                         3              3           Fulham
# Bruno Fernandes                      3              3   Manchester Utd
# Chris Wood                           3              3  Nott'ham Forest
# Erling Haaland                       3              2  Manchester City

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         571 non-null    object
#  1   nation                       571 non-null    object
#  2   position                     571 non-null    object
#  3   team                         571 non-null    object
#  4   age                          571 non-null    object
#  5   born                         571 non-null    object
#  6   played                       571 non-null    int64
#  7   starts                       571 non-null    int64
#  8   minutes                      571 non-null    int64
#  9   goals                        571 non-null    int64
#  10  assists                      571 non-null    int64
#  11  penalty_kicks                571 non-null    int64
#  12  penalty_kick_attempts        571 non-null    int64
# ...

# %%
data.groupby('name')[['minutes','position','team']].sum().sort_values(by= 'minutes',ascending=False).head(10)
# Out:
#                  minutes position             team
# name
# Bernd Leno          3330       GK           Fulham
# Nathan Collins      3330       DF        Brentford
# David Raya          3330       GK          Arsenal
# Dean Henderson      3330       GK   Crystal Palace
# Matz Sels           3330       GK  Nott'ham Forest
# Jordan Pickford     3330       GK          Everton
# Bryan Mbeumo        3324       FW        Brentford
# Mohamed Salah       3281       FW        Liverpool
# Moisés Caicedo      3261    MF,DF          Chelsea
# Max Kilman          3258       DF         West Ham

# %%
data.describe()
# Out:
#            played      starts      minutes       goals     assists  \
# count  571.000000  571.000000   571.000000  571.000000  571.000000
# mean    19.718039   14.255692  1280.558669    1.852890    1.378284
# std     11.905889   12.026190  1028.756114    3.491755    2.227535
# min      1.000000    0.000000     1.000000    0.000000    0.000000
# 25%      9.000000    3.000000   319.000000    0.000000    0.000000
# 50%     21.000000   12.000000  1060.000000    0.000000    0.000000
# 75%     31.000000   25.000000  2183.000000    2.000000    2.000000
# max     37.000000   37.000000  3330.000000   28.000000   18.000000
#
#        penalty_kicks  penalty_kick_attempts      yellow         red  \
# count     571.000000             571.000000  571.000000  571.000000
# mean        0.113835               0.138354    2.751313    0.087566
# std         0.667018               0.720709    2.750020    0.300939
# min         0.000000               0.000000    0.000000    0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         571 non-null    object
#  1   nation                       571 non-null    object
#  2   position                     571 non-null    object
#  3   team                         571 non-null    object
#  4   age                          571 non-null    object
#  5   born                         571 non-null    object
#  6   played                       571 non-null    int64
#  7   starts                       571 non-null    int64
#  8   minutes                      571 non-null    int64
#  9   goals                        571 non-null    int64
#  10  assists                      571 non-null    int64
#  11  penalty_kicks                571 non-null    int64
#  12  penalty_kick_attempts        571 non-null    int64
# ...

# %%
salary = pd.read_csv('/content/player_salaries.csv')
salary.head()
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 684 entries, 0 to 683
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Player    684 non-null    object
#  1   Nation    503 non-null    object
#  2   Position  677 non-null    object
#  3   Team      684 non-null    object
#  4   Age       684 non-null    int64
#  5   Weekly    684 non-null    int64
#  6   Annual    684 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 37.5+ KB

# %%
annual_salary = salary[['Player','Annual']]
weekly_salary = salary[['Player','Weekly']]

# %%
annual_salary
# Out:
#                 Player    Annual
# 0      Kevin De Bruyne  25402046
# 1       Erling Haaland  23814418
# 2             Casemiro  22226790
# 3        Mohamed Salah  22226790
# 4      Bruno Fernandes  19051534
# ..                 ...       ...
# 679  Cameron Humphreys     68072
# 680      George Abbott     52356
# 681      Rico Richards     52356
# 682        Kobei Moore     41885
# 683    Luca Stephenson     27923
#
# [684 rows x 2 columns]

# %%
weekly_salary[weekly_salary['Player']=='Bruno Fernandes']
# Out:
#             Player  Weekly
# 4  Bruno Fernandes  366376

# %%
data[data['name']=='Liam Delap']
# Out:
#            name   nation position          team   age    born  played  starts  \
# 126  Liam Delap  England       FW  Ipswich Town  22.0  2003.0      36      32
#
#      minutes  goals  assists  penalty_kicks  penalty_kick_attempts  yellow  \
# 126     2572     12        2              2                      2      10
#
#      red  expected_goals  progressive_carries  progressive_passes  \
# 126    0             9.3                   60                  30
#
#      received_progressive_passes
# 126                          107

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
goals = data.loc[60:70 , 'goals'].values
names = data.loc[60:70 , 'name'].values
assists = data.loc[60:70,'assists'].values

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-ticks')
plt.figure(figsize = (20 , 10))
plt.grid(True)
plt.plot(names, goals, color='r', marker='o', linewidth=2, markersize=8, label='Goals')
plt.plot(names , assists , c = 'k', marker = 'o' , label = 'Assists')
plt.title('Goals & Assists' , fontsize = 22)
plt.ylabel('Number' , fontsize = 22)
plt.xlim(left = 0 , right = 10)
plt.ylim(bottom =0 , top =13)
plt.legend(fontsize =15)

# %%
names = data['name'].values
names
salaries = salary['Player'].values
annual = salary['Annual'].values
annual
annuall = np.zeros((571,1))

# %%
for i in range(len(names)):
  for q in range(len(names)):
     if names[i] == salaries[q]:
      annuall[i]= annual[q]

# %%
data.drop('annual' , axis = 1 , inplace = True)

# %%
data.insert(19 , 'annual' , annuall)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         571 non-null    object
#  1   nation                       571 non-null    object
#  2   position                     571 non-null    object
#  3   team                         571 non-null    object
#  4   age                          571 non-null    object
#  5   born                         571 non-null    object
#  6   played                       571 non-null    int64
#  7   starts                       571 non-null    int64
#  8   minutes                      571 non-null    int64
#  9   goals                        571 non-null    int64
#  10  assists                      571 non-null    int64
#  11  penalty_kicks                571 non-null    int64
#  12  penalty_kick_attempts        571 non-null    int64
# ...

# %%
data.head(10)
# Out:
#                 name         nation position             team   age    born  \
# 0         Max Aarons        England       DF      Bournemouth  25.0  2000.0
# 1  Joshua Acheampong        England       DF          Chelsea  19.0  2006.0
# 2        Tyler Adams  United States       MF      Bournemouth  26.0  1999.0
# 3   Tosin Adarabioyo        England       DF          Chelsea  27.0  1997.0
# 4      Simon Adingra   Cote dIvoire    FW,MF         Brighton  23.0  2002.0
# 5   Emmanuel Agbadou   Cote dIvoire       DF           Wolves  27.0  1997.0
# 6     Asher Agbinone        England       MF   Crystal Palace  19.0  2005.0
# 7           Ola Aina        Nigeria       DF  Nott'ham Forest  28.0  1996.0
# 8    Rayan Aït-Nouri        Algeria       DF           Wolves  23.0  2001.0
# 9    Kristoffer Ajer         Norway       DF        Brentford  27.0  1998.0
#
#    played  starts  minutes  goals  assists  penalty_kicks  \
# 0       3       1       86      0        0              0
# ...

# %%
data.rename(columns={'annual':'annual_salary'},inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 571 entries, 0 to 570
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         571 non-null    object
#  1   nation                       571 non-null    object
#  2   position                     571 non-null    object
#  3   team                         571 non-null    object
#  4   age                          571 non-null    object
#  5   born                         571 non-null    object
#  6   played                       571 non-null    int64
#  7   starts                       571 non-null    int64
#  8   minutes                      571 non-null    int64
#  9   goals                        571 non-null    int64
#  10  assists                      571 non-null    int64
#  11  penalty_kicks                571 non-null    int64
#  12  penalty_kick_attempts        571 non-null    int64
# ...

# %%
data.head(10)
# Out:
#                 name         nation position             team   age    born  \
# 0         Max Aarons        England       DF      Bournemouth  25.0  2000.0
# 1  Joshua Acheampong        England       DF          Chelsea  19.0  2006.0
# 2        Tyler Adams  United States       MF      Bournemouth  26.0  1999.0
# 3   Tosin Adarabioyo        England       DF          Chelsea  27.0  1997.0
# 4      Simon Adingra   Cote dIvoire    FW,MF         Brighton  23.0  2002.0
# 5   Emmanuel Agbadou   Cote dIvoire       DF           Wolves  27.0  1997.0
# 6     Asher Agbinone        England       MF   Crystal Palace  19.0  2005.0
# 7           Ola Aina        Nigeria       DF  Nott'ham Forest  28.0  1996.0
# 8    Rayan Aït-Nouri        Algeria       DF           Wolves  23.0  2001.0
# 9    Kristoffer Ajer         Norway       DF        Brentford  27.0  1998.0
#
#    played  starts  minutes  goals  assists  penalty_kicks  \
# 0       3       1       86      0        0              0
# ...

# %%
data.groupby('name')[['annual_salary','team']].max().sort_values(by='annual_salary',ascending= False).head(10)
# Out:
#                 annual_salary             team
# name
# Kevin De Bruyne    25402046.0  Manchester City
# Erling Haaland     23814418.0  Manchester City
# Casemiro           22226790.0   Manchester Utd
# Mohamed Salah      22226790.0        Liverpool
# Omar Marmoush      20593224.0  Manchester City
# Jack Grealish      19051534.0  Manchester City
# Bernardo Silva     19051534.0  Manchester City
# Marcus Rashford    19051534.0   Manchester Utd
# Bruno Fernandes    19051534.0   Manchester Utd
# Kai Havertz        17781432.0          Arsenal
